# %% [markdown]
# Face Recognition
# Applied Math Project
# Mohamed Ali (MSCV) and Elizaveta Genke (MAIA)

# %%
#Import necessary libraries
import numpy as np
import pandas as pd
import glob, os
import matplotlib.pylab as plt
import re

from skimage import transform as tf
from skimage import data
from skimage import io


from skimage import  io

import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from skimage import io
from skimage import transform as tf
from skimage import data, color
from skimage.transform import rescale, resize
import pandas as pd

# %matplotlib inline

# %% [markdown]
# Open all .txt files in the folder and save coordinates of face features (right eye, left eye, nose tip, right mouth corner, left mouth corner) to an array (tabular data structure from pandas library). Sort this array in alphabetical order using names.

# %%
files = glob.glob("./Train set/*.txt")
L = []
names =[]
for i in range(len(files)):
    x = np.loadtxt(files[i]).flatten()
    names.append(files[i].strip('./txt'))
    output = np.hstack(x)
    L.append(output)
    output = np.array(L)
    df = pd.DataFrame(output,index=names)
    
columns = pd.MultiIndex.from_product([['Right eye', 'Left eye', 'Nose tip', 'Right mouth corner' , 'Left mouth corner']
                                      , ['X', 'Y']],
names=['Feature', 'Position '])

df.columns=columns
df = df.sort_index()

# %% [markdown]
# Let's plot all the facial feature positions in one plot:

# %%
plt.figure(figsize=(5,5))
plt.plot(output[:,0::2],output[:,1::2],'.');

# %% [markdown]
# Create an array of predefined feature positions in a 64x64 window.

# %%
src = np.array([[13, 20], [50, 20], [34, 34], [16, 50], [48, 50]])

# %% [markdown]
# Define functions to open image as grey and to estimate transformation (using AffineTransform function).

# %%
def GetImg(file):
    img = io.imread(file,as_grey=True)
    return img

# %%
def TransForm(src,dst):
    tform3 = tf.AffineTransform()
    tform3.estimate(src, dst)
    return tform3.params

# %% [markdown]
# Load all images and sort them.

# %%
Imgfiles = glob.glob("./*.jpg")

# %% [markdown]
# Estimate Affine transform of every image facial features to predefined positions in a 64x64 window. Apply this transform to every pixel and save this to '/warped' folder.

# %%
Imgfiles = sorted(glob.glob("./*.jpg"))
files = sorted(glob.glob("./*.txt"))

for i in range(len(Imgfiles)):
    img = GetImg(Imgfiles[i])
    x = np.loadtxt(files[i]).flatten()
    x = x.reshape(5,2) 
    para = TransForm(src,x)  
    warped = tf.warp( img, para, output_shape=(64,64))
    io.imsave('warped/{}.jpg'.format(Imgfiles[i].strip('./jpg ')),warped)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %% [markdown]
# Define function that converts image into a vector in d-dimensional space (d=64x64=4096). Load a collection of image files as vectors and concatenate all images in the image collection into an array.

# %%
def flatten(img):
    out=io.imread(img).flatten()
    return out

image_files = sorted(glob.glob("train_images/*.jpg"))
images = io.ImageCollection(image_files,load_func=flatten)
stack = io.concatenate_images(images)

# %% [markdown]
# Calculate mean vector and compute covariance matrix of "centralised" matrix of images using the formula below:
# \begin{equation}
#  \Sigma = \frac{1}{p-1} D^T D
# \end{equation}

# %%
mean_vec = np.mean(stack,axis=0)
print(mean_vec)
cov_mat = (stack - mean_vec).T.dot((stack - mean_vec)) / (stack.shape[0]-1)
print(cov_mat.shape)
io.imshow(cov_mat);
# Out:
# [  84.20833333   85.00833333   85.075      ...,  104.79166667  104.89166667
#   105.9       ]
# (4096, 4096)

# %% [markdown]
# Let's show mean image with points corresponding to predefined positions of facial features over it.

# %%
mean_Face = mean_vec.reshape(64,64) 
plt.imshow(mean_Face,cmap='gray')
plt.scatter(x=[13, 50, 34, 16, 48], y=[20, 20, 34, 50, 50])
plt.show()

# %% [markdown]
# Then we compute eigenvalues and eigenvectors of the covariance matrix.

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[ -1.23872990e-02 +0.00000000e+00j  -1.63467497e-02 +0.00000000e+00j
#     2.48350354e-02 +0.00000000e+00j ...,   9.69189532e-04 +2.47394483e-04j
#     9.69189532e-04 -2.47394483e-04j  -8.70811054e-04 +0.00000000e+00j]
#  [ -1.23622627e-02 +0.00000000e+00j  -1.70375013e-02 +0.00000000e+00j
#     2.71336239e-02 +0.00000000e+00j ...,  -1.59918432e-05 +1.07847207e-05j
#    -1.59918432e-05 -1.07847207e-05j  -1.26833310e-04 +0.00000000e+00j]
#  [ -1.23186351e-02 +0.00000000e+00j  -1.58510473e-02 +0.00000000e+00j
#     3.09597062e-02 +0.00000000e+00j ...,   1.34755941e-04 +3.62490883e-05j
#     1.34755941e-04 -3.62490883e-05j  -6.92179283e-05 +0.00000000e+00j]
#  ...,
#  [ -1.57836129e-02 +0.00000000e+00j   3.49964318e-02 +0.00000000e+00j
#    -8.05173758e-03 +0.00000000e+00j ...,   6.68898187e-04 -3.02494176e-03j
#     6.68898187e-04 +3.02494176e-03j   1.57937019e-04 +0.00000000e+00j]
#  [ -1.48873474e-02 +0.00000000e+00j   3.51409754e-02 +0.00000000e+00j
#    -8.87077212e-03 +0.00000000e+00j ...,   4.76729447e-03 +4.73995301e-03j
#     4.76729447e-03 -4.73995301e-03j  -3.27071198e-03 +0.00000000e+00j]
#  [ -1.46800328e-02 +0.00000000e+00j   3.56445687e-02 +0.00000000e+00j
#    -1.00729068e-02 +0.00000000e+00j ...,  -3.43013705e-04 +4.97939417e-03j
#    -3.43013705e-04 -4.97939417e-03j  -2.86595153e-03 +0.00000000e+00j]]
#
# Eigenvalues
# [  1.84318620e+06 +0.00000000e+00j   7.86612053e+05 +0.00000000e+00j
#    3.06299397e+05 +0.00000000e+00j ...,   6.80213451e-14 +5.27301215e-14j
#    6.80213451e-14 -5.27301215e-14j  -1.07665776e-13 +0.00000000e+00j]

# %% [markdown]
# After this we choose 100 eigenvectors corresponding to the highest eigenvalues and create an array out of them (Ф projection matrix).

# %%
# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
def getKey(item):
    return item[0]
eig_pairs = sorted(eig_pairs, key=getKey,reverse=True) 
eig_pairs = eig_pairs[0:100]

# %%
L=[]
for i in eig_pairs:
    L.append(i[1])
EigVecs = np.array(L)

# %% [markdown]
# Then we create a matrix of every image feature vectors. This feature vectors we get by projecting every image into a PCA space by using formula:
# \begin{equation}
# \phi_i=X_iФ
# \end{equation}

# %%
Feature = []

for i in range(len(images)):
    Feature.append(images[i].dot(np.real(EigVecs).T))
    
Feature = np.array(Feature)
Feature.shape
# Out:
# (120, 100)

# %% [markdown]
# We create extract names for images in train and test set.

# %%
import os

train_names=sorted(glob.glob("train_images/*.txt"))
labels_train=[]
for i in range (len(images)):
    filename_w_ext = os.path.basename(train_names[i])
    filename, file_extension = os.path.splitext(filename_w_ext)
    labels_train.append(re.sub(r'\d+', '', filename))
labels_train = np.array(labels_train)
print (labels_train)
# Out:
# ['Ali' 'Ali' 'Ali' 'Alyafi_' 'Alyafi_' 'Alyafi_' 'Anaghan' 'Anaghan'
#  'Anaghan' 'Asraf Ali_' 'Asraf Ali_' 'Asraf Ali_' 'Birhanu' 'Birhanu'
#  'Birhanu' 'Boudissa' 'Boudissa' 'Boudissa' 'Doiriel' 'Doiriel' 'Doiriel'
#  'Dudhagara' 'Dudhagara' 'Dudhagara' 'Fahad' 'Fahad' 'Fahad' 'Flavien'
#  'Flavien' 'Flavien' 'Genke' 'Genke' 'Genke' 'Hasan' 'Hasan' 'Hasan'
#  'Herrera_' 'Herrera_' 'Herrera_' 'KB' 'KB' 'KB' 'Kozynets' 'Kozynets'
#  'Kozynets' 'Malav' 'Malav' 'Malav' 'Mohammed Abdul' 'Mohammed Abdul'
#  'Mohammed Abdul' 'Ngige' 'Ngige' 'Ngige' 'Pandey' 'Pandey' 'Pandey'
#  'Rakic' 'Rakic' 'Rakic' 'Reimmer' 'Reimmer' 'Reimmer' 'Shah' 'Shah' 'Shah'
#  'Sonizara' 'Sonizara' 'Sonizara' 'Sulaiman_' 'Sulaiman_' 'Sulaiman_'
#  'Vaishnav' 'Vaishnav' 'Vaishnav' 'Yawson' 'Yawson' 'Yawson' 'antoine'
#  'antoine' 'antoine' 'benali' 'benali' 'benali' 'berada' 'berada' 'berada'
#  'brianna' 'brianna' 'brianna' 'gulnur' 'gulnur' 'gulnur' 'khan' 'khan'
#  'khan' 'lav' 'lav' 'lav' 'ochoa' 'ochoa' 'ochoa' 'rockenbach' 'rockenbach'
#  'rockenbach' 'roger' 'roger' 'roger' 'toshpulatov' 'toshpulatov'
#  'toshpulatov' 'tushar' 'tushar' 'tushar' 'valencia' 'valencia' 'valencia'
#  'zotova' 'zotova' 'zotova']

# %%
test_names=sorted(glob.glob("test_images/*.txt"))
labels_test=[]
for i in range (len(test_names)):
    filename_w_ext = os.path.basename(test_names[i])
    filename, file_extension = os.path.splitext(filename_w_ext)
    labels_test.append(re.sub(r'\d+', '', filename))
labels_test = np.array(labels_test)
print (labels_test)
# Out:
# ['Ali' 'Ali' 'Alyafi_' 'Alyafi_' 'Anaghan' 'Anaghan' 'Asraf Ali_'
#  'Asraf Ali_' 'Birhanu' 'Birhanu' 'Boudissa' 'Boudissa' 'Doiriel' 'Doiriel'
#  'Dudhagara' 'Dudhagara' 'Fahad' 'Fahad' 'Flavien' 'Flavien' 'Genke'
#  'Genke' 'Hasan' 'Hasan' 'Herrera_' 'Herrera_' 'KB' 'KB' 'Kozynets'
#  'Kozynets' 'Malav' 'Malav' 'Mohammed Abdul' 'Mohammed Abdul' 'Ngige'
#  'Ngige' 'Pandey' 'Pandey' 'Rakic' 'Rakic' 'Reimmer' 'Reimmer' 'Sonizara'
#  'Sonizara' 'Sulaiman_' 'Sulaiman_' 'Vaishnav' 'Vaishnav' 'Yawson' 'Yawson'
#  'antoine' 'antoine' 'benali' 'benali' 'berada' 'berada' 'brianna'
#  'brianna' 'gulnur' 'gulnur' 'khan' 'khan' 'lav' 'lav' 'ochoa' 'ochoa'
#  'rockenbach' 'rockenbach' 'roger' 'roger' 'shah' 'shah' 'toshpulatov'
#  'toshpulatov' 'tushar' 'tushar' 'valencia' 'valencia' 'zotova' 'zotova']

# %% [markdown]
# Then we start testing our face recognition system. For every image from training set we calculate feature vector

# %%
from numpy.linalg import norm
epsilon = 0

test_images = io.ImageCollection('test_images/*.jpg',load_func=flatten)
for i in range (len(test_images)):
    test_feature=test_images[i].dot(np.real(EigVecs).T)
    distance=norm(Feature-test_feature, axis=1, ord=2) 
    position = np.where(distance == distance.min())
    position = np.array(position)
    print(labels_test[i], ' : matched as --> ',labels_train[position.item()])
    if (labels_test[i]!=labels_train[position.item()]):
        epsilon = epsilon + 1
    
    
print ('The accuracy is', 1-epsilon/(len(test_images))) 

test_feature=test_images[1].dot(np.real(EigVecs).T)
distance=norm(Feature-test_feature, axis=1, ord=2) 
position = np.where(distance == distance.min())
position = np.array(position)
plt.subplot(121)
plt.imshow(test_images[1].reshape(64,64))
plt.subplot(122)
plt.imshow(image_files[position])
# Out:
# Ali  : matched as -->  Ali
# Ali  : matched as -->  Ali
# Alyafi_  : matched as -->  Alyafi_
# Alyafi_  : matched as -->  Mohammed Abdul
# Anaghan  : matched as -->  tushar
# Anaghan  : matched as -->  Anaghan
# Asraf Ali_  : matched as -->  Asraf Ali_
# Asraf Ali_  : matched as -->  Pandey
# Birhanu  : matched as -->  Birhanu
# Birhanu  : matched as -->  Birhanu
# Boudissa  : matched as -->  Boudissa
# Boudissa  : matched as -->  Boudissa
# Doiriel  : matched as -->  Doiriel
# Doiriel  : matched as -->  Doiriel
# Dudhagara  : matched as -->  Dudhagara
# Dudhagara  : matched as -->  Dudhagara
# Fahad  : matched as -->  Fahad
# Fahad  : matched as -->  Fahad
# Flavien  : matched as -->  Fahad
# Flavien  : matched as -->  Flavien
# Genke  : matched as -->  Genke
# Genke  : matched as -->  Genke
# Hasan  : matched as -->  Hasan
# Hasan  : matched as -->  Hasan
# Herrera_  : matched as -->  Herrera_
# Herrera_  : matched as -->  Herrera_
# KB  : matched as -->  KB
# KB  : matched as -->  KB
# Kozynets  : matched as -->  Hasan
# Kozynets  : matched as -->  Hasan
# Malav  : matched as -->  Malav
# Malav  : matched as -->  Malav
# Mohammed Abdul  : matched as -->  Mohammed Abdul
# Mohammed Abdul  : matched as -->  lav
# Ngige  : matched as -->  Ngige
# Ngige  : matched as -->  Ngige
# Pandey  : matched as -->  Pandey
# Pandey  : matched as -->  Pandey
# Rakic  : matched as -->  Rakic
# Rakic  : matched as -->  Rakic
# Reimmer  : matched as -->  Reimmer
# Reimmer  : matched as -->  Reimmer
# Sonizara  : matched as -->  tushar
# Sonizara  : matched as -->  Reimmer
# Sulaiman_  : matched as -->  Sonizara
# Sulaiman_  : matched as -->  Sonizara
# Vaishnav  : matched as -->  Boudissa
# Vaishnav  : matched as -->  Anaghan
# Yawson  : matched as -->  Hasan
# Yawson  : matched as -->  Genke
# antoine  : matched as -->  toshpulatov
# antoine  : matched as -->  tushar
# benali  : matched as -->  tushar
# benali  : matched as -->  Boudissa
# berada  : matched as -->  benali
# berada  : matched as -->  KB
# brianna  : matched as -->  tushar
# brianna  : matched as -->  toshpulatov
# gulnur  : matched as -->  toshpulatov
# gulnur  : matched as -->  toshpulatov
# khan  : matched as -->  Boudissa
# khan  : matched as -->  Boudissa
# lav  : matched as -->  toshpulatov
# lav  : matched as -->  toshpulatov
# ochoa  : matched as -->  toshpulatov
# ochoa  : matched as -->  Mohammed Abdul
# rockenbach  : matched as -->  toshpulatov
# rockenbach  : matched as -->  toshpulatov
# roger  : matched as -->  Herrera_
# roger  : matched as -->  Herrera_
# shah  : matched as -->  tushar
# shah  : matched as -->  toshpulatov
# toshpulatov  : matched as -->  toshpulatov
# toshpulatov  : matched as -->  toshpulatov
# tushar  : matched as -->  tushar
# tushar  : matched as -->  tushar
# valencia  : matched as -->  valencia
# valencia  : matched as -->  valencia
# zotova  : matched as -->  zotova
# zotova  : matched as -->  zotova
# The accuracy is 0.5375
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-606d8cb2f4f1> in <module>()
#      22 plt.imshow(test_images[1].reshape(64,64))
#      23 plt.subplot(122)
# ---> 24 plt.imshow(image_files[position])
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
ImageTest1 = images[50].dot(np.real(EigVecs).T);

# %%
ImageTest1.shape
# Out:
# (100,)

# %%
a = norm(Feature-ImageTest1, axis=1, ord=2)

# %%
print(Pos.item())
# Out:
# 50

# %%
S = sorted(Imgfiles)
io.imshow(S[Pos.item()]);

# %%
Names = sorted(files)

# %%
PrintName(Names[Pos.item()])
# Out:
# Best Matched Image of : Genke

# %%
def PrintName(ImageName):
    outputName = re.sub(r'\d+', '', ImageName.strip('./txt '))
    print ('Best Matched Image of : ' + outputName)
